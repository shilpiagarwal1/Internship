# %%
import pandas as pd
import numpy as np
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
driver=webdriver.Chrome(r'chromedriver.exe')

# %%
url='https://www.amazon.com/s?k=silk+sarees&qid=1631865567&ref=sr_pg_1'
driver.get(url)

# %%
urlList=[]


url1=driver.find_elements_by_xpath("//div[@class='a-text-center']/ul/li[2]/a")

for i in url1:
    print(i.get_attribute("href"))
    path=i.get_attribute("href")
    urlList.append(path)
   

url2=driver.find_elements_by_xpath("//div[@class='a-text-center']/ul/li[3]/a")
for i in url2:
    print(i.get_attribute("href"))
    path=i.get_attribute("href")
    urlList.append(path)

url3=driver.find_elements_by_xpath("//div[@class='a-text-center']/ul/li[4]/a")
for i in url3:
    print(i.get_attribute("href"))
    path=i.get_attribute("href")
    urlList.append(path)
    

urlList.append('https://www.amazon.com/s?k=silk+sarees&page=3&qid=1631865609&ref=sr_pg_4')
   
urlList
# Out:
# https://www.amazon.com/s?k=silk+sarees&qid=1631878254&ref=sr_pg_1
# https://www.amazon.com/s?k=silk+sarees&page=2&qid=1631878254&ref=sr_pg_2
# https://www.amazon.com/s?k=silk+sarees&page=3&qid=1631878254&ref=sr_pg_3
# ['https://www.amazon.com/s?k=silk+sarees&qid=1631878254&ref=sr_pg_1',
#  'https://www.amazon.com/s?k=silk+sarees&page=2&qid=1631878254&ref=sr_pg_2',
#  'https://www.amazon.com/s?k=silk+sarees&page=3&qid=1631878254&ref=sr_pg_3',
#  'https://www.amazon.com/s?k=silk+sarees&page=3&qid=1631865609&ref=sr_pg_4']

# %%
imagelist=[]
try:
    
    for i in urlList:
        driver.get(i)
        time.sleep(2)
        p1=driver.find_elements_by_xpath("//img[@class='s-image']")
        for i in p1:
            print(i.get_attribute("src"))
            imagelist.append(i.get_attribute("src"))
except NoSuchElementException as e:
    print(e)
# Out:
# https://m.media-amazon.com/images/I/81A+O8-wBeL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91u6L16oygL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71jlWeXsuPL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/711JITLeOIL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81nceLJxqDL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51u0DB1ffJL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81aWlr+pY+L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91SwBC2-2PL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91ZagwCkpsL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71DUSCyWJ2L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81MaKf8ZpML._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/9177XEfUTHL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91hEF5wznaL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71d-BlWM6ZL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51p96FN1Z1L._AC_UL320_.jpg
# ...

# %%
count=1
for j in imagelist:
    driver.get(j)
    driver.get_screenshot_as_file("saree"+ str(count)+".png")
    count=count+1
print(count)
# Out:
# 230

# %%
#Scrapping Images of Trouser(men)

# %%
driver.get('https://www.amazon.com/s?k=trousers+for+men&crid=1NA2ULS7GDRTM&ref=nb_sb_ss_ts-doa-p_2_9')

# %%
#getting urlList of Trouser(men)
urlList1=[]


url1=driver.find_elements_by_xpath("//div[@class='a-text-center']/ul/li[@class='a-selected']/a")

for i in url1:
    print(i.get_attribute("href"))
    path=i.get_attribute("href")
    urlList1.append(path)
url2=driver.find_elements_by_xpath("//div[@class='a-text-center']/ul/li[@class='a-normal']/a") 
for i in url2:
    print(i.get_attribute("href"))
    path=i.get_attribute("href")
    urlList1.append(path)
urlList1
# Out:
# https://www.amazon.com/s?k=trousers+for+men&crid=1NA2ULS7GDRTM&qid=1631878827&ref=sr_pg_1
# https://www.amazon.com/s?k=trousers+for+men&page=2&crid=1NA2ULS7GDRTM&qid=1631878827&ref=sr_pg_2
# https://www.amazon.com/s?k=trousers+for+men&page=3&crid=1NA2ULS7GDRTM&qid=1631878827&ref=sr_pg_3
# ['https://www.amazon.com/s?k=trousers+for+men&crid=1NA2ULS7GDRTM&qid=1631878827&ref=sr_pg_1',
#  'https://www.amazon.com/s?k=trousers+for+men&page=2&crid=1NA2ULS7GDRTM&qid=1631878827&ref=sr_pg_2',
#  'https://www.amazon.com/s?k=trousers+for+men&page=3&crid=1NA2ULS7GDRTM&qid=1631878827&ref=sr_pg_3']

# %%
#getting source of all images of trouser and saved in imagelist_trouser.
imagelist_trouser=[]
for i in urlList1:
    driver.get(i)
    time.sleep(2)
    p2=driver.find_elements_by_xpath("//img[@class='s-image']")
    for i in p2:
        print(i.get_attribute("src"))
        imagelist_trouser.append(i.get_attribute("src"))
# Out:
# https://m.media-amazon.com/images/I/71-X9pQe0uL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51wFG9KpNeL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61WwnDy0axS._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/514YpxhnM6L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81YCt8lyCeL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71FlV5Bur9L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71KrtPSuc6L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71IW6dw0BxL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71VXHsrpMKL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81hq2vVdunL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71gn7gSHU+L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61ficSPslLL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71KiXKeYedL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/6136Cq-mNRL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/715JZviwaeL._AC_UL320_.jpg
# ...

# %%
#saving images of all trouser
count1=1
for j in imagelist_trouser:
    driver.get(j)
    driver.get_screenshot_as_file("trouser"+ str(count)+".png")
    count1=count1+1
print(count1)
# Out:
# 417

# %%
#Scrapping data of Jeans(men)

# %%
driver.get('https://www.amazon.com/s?k=jeans+for+men&crid=2X1QWFSCZDIQX&sprefix=jeans+%2Caps%2C422&ref=nb_sb_ss_ts-doa-p_3_6')

# %%
#getting urlList of Jeans(men)
urlListjeans=[]


urlj=driver.find_elements_by_xpath("//div[@class='a-text-center']/ul/li[@class='a-selected']/a")

for i in urlj:
    print(i.get_attribute("href"))
    path=i.get_attribute("href")
    urlListjeans.append(path)
urlje=driver.find_elements_by_xpath("//div[@class='a-text-center']/ul/li[@class='a-normal']/a") 
for i in urlje:
    print(i.get_attribute("href"))
    path=i.get_attribute("href")
    urlListjeans.append(path)
urlListjeans
# Out:
# https://www.amazon.com/s?k=jeans+for+men&crid=2X1QWFSCZDIQX&qid=1632043719&sprefix=jeans+%2Caps%2C422&ref=sr_pg_1
# https://www.amazon.com/s?k=jeans+for+men&page=2&crid=2X1QWFSCZDIQX&qid=1632043719&sprefix=jeans+%2Caps%2C422&ref=sr_pg_2
# https://www.amazon.com/s?k=jeans+for+men&page=3&crid=2X1QWFSCZDIQX&qid=1632043719&sprefix=jeans+%2Caps%2C422&ref=sr_pg_3
# ['https://www.amazon.com/s?k=jeans+for+men&crid=2X1QWFSCZDIQX&qid=1632043719&sprefix=jeans+%2Caps%2C422&ref=sr_pg_1',
#  'https://www.amazon.com/s?k=jeans+for+men&page=2&crid=2X1QWFSCZDIQX&qid=1632043719&sprefix=jeans+%2Caps%2C422&ref=sr_pg_2',
#  'https://www.amazon.com/s?k=jeans+for+men&page=3&crid=2X1QWFSCZDIQX&qid=1632043719&sprefix=jeans+%2Caps%2C422&ref=sr_pg_3']

# %%
#getting source of all images of Jeans and saved in imagelist_jeans.
imagelist_jeans=[]
for i in urlListjeans:
    driver.get(i)
    p3=driver.find_elements_by_xpath("//img[@class='s-image']")
    for i in p3:
        print(i.get_attribute("src"))
        imagelist_jeans.append(i.get_attribute("src"))
# Out:
# https://m.media-amazon.com/images/I/71d3VshsiBS._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81sG0mVALDL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61q0hOtVtnL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81GxuswMorL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81LugvYtlGL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71-KKTMxOsL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71bxUBa7ysL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/817qC6rtrHS._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61Oqtc0XA9L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81W3vV6VFoL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81s1wc2KJgL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81L3+8MPwlL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71C2uD622wL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81WJ8OsJSDL._AC_UL320_.jpg
# ...

# %%
#saving images of all Jeans
count2=1
for j in imagelist_jeans:
    driver.get(j)
    driver.get_screenshot_as_file("Jeans"+ str(count)+".png")
    count2=count2+1
print(count2)
# Out:
# 197

# %%
import requests
for i in range(len(imagelist_jeans)):

    if i >= 300:

        break

    print("Downloading {0} of {1} images" .format(i, 300))

    response= requests.get(imagelist_jeans[i])

    file = open(r"C:\Users\SHILPI\Images\new"+str(i)+".jpg", "wb")

    file.write(response.content)

# %% [markdown]
# # Image Classification

# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
import cv2
width, height= 224, 224
img = cv2.imread('/content/drive/MyDrive/Train/Jeans/new1.jpg')
img_resized = cv2.resize(img,(width, height))

# %%
img_resized.shape
# Out:
# (224, 224, 3)

# %%
img.shape
# Out:
# (320, 141, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(img_resized)

# %%
plt.imshow(cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Train',
                                                 target_size = (width, height),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')
# Out:
# Found 581 images belonging to 3 classes.

# %%
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Test',
                                            target_size = (width, height),
                                            batch_size = 5,
                                            class_mode = 'categorical')
# Out:
# Found 15 images belonging to 3 classes.

# %%
IMAGE_SIZE = [224, 224]


# add preprocessing layer to the front of VGG
vgg = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# don't train existing weights
for layer in vgg.layers:
  layer.trainable = False
  

  
  # useful for getting number of classes
folders = glob('/content/drive/MyDrive/Train/*')
  

# our layers - you can add more if you want
x = Flatten()(vgg.output)
#x = Dense(1000, activation='relu')(x)
prediction = Dense(len(folders),activation='softmax')(x)

# create a model object
model = Model(inputs=vgg.input, outputs=prediction)

# view the structure of the model
model.summary()

# tell the model what cost and optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
folders
# Out:
# ['/content/drive/MyDrive/Train/Jeans',
#  '/content/drive/MyDrive/Train/Saree',
#  '/content/drive/MyDrive/Train/Trouser']

# %%
# fit the model
r = model.fit( training_set,validation_data=test_set,epochs=2)
# Out:
# Epoch 1/2
# 19/19 [==============================] - 231s 12s/step - loss: 0.3576 - accuracy: 0.8485 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 2/2
# 19/19 [==============================] - 177s 9s/step - loss: 0.0612 - accuracy: 0.9759 - val_loss: 0.0055 - val_accuracy: 1.0000

# %%
from tensorflow.keras.utils import plot_model
plot_model(model,to_file='model.png',show_shapes=True, show_layer_names=True)
